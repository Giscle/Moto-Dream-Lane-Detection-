# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import math
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import MinMaxScaler
from collections import defaultdict
from scipy.linalg import block_diag
from __future__ import division

# %%
class LaneTracker:
    def __init__(self, n_lanes, proc_noise_scale, meas_noise_scale, process_cov_parallel=0, proc_noise_type='white'):
        self.n_lanes = n_lanes
        self.meas_size = 4 * self.n_lanes
        self.state_size = self.meas_size * 2
        self.contr_size = 0

        self.kf = cv2.KalmanFilter(self.state_size, self.meas_size, self.contr_size)
        self.kf.transitionMatrix = np.eye(self.state_size, dtype=np.float32)
        self.kf.measurementMatrix = np.zeros((self.meas_size, self.state_size), np.float32)
        for i in range(self.meas_size):
            self.kf.measurementMatrix[i, i*2] = 1

        if proc_noise_type == 'white':
            block = np.matrix([[0.25, 0.5],
                               [0.5, 1.]], dtype=np.float32)
            self.kf.processNoiseCov = block_diag(*([block] * self.meas_size)) * proc_noise_scale
        if proc_noise_type == 'identity':
            self.kf.processNoiseCov = np.eye(self.state_size, dtype=np.float32) * proc_noise_scale
        for i in range(0, self.meas_size, 2):
            for j in range(1, self.n_lanes):
                self.kf.processNoiseCov[i, i+(j*8)] = process_cov_parallel
                self.kf.processNoiseCov[i+(j*8), i] = process_cov_parallel

        self.kf.measurementNoiseCov = np.eye(self.meas_size, dtype=np.float32) * meas_noise_scale

        self.kf.errorCovPre = np.eye(self.state_size)

        self.meas = np.zeros((self.meas_size, 1), np.float32)
        self.state = np.zeros((self.state_size, 1), np.float32)

        self.first_detected = False

    def _update_dt(self, dt):
        for i in range(0, self.state_size, 2):
            self.kf.transitionMatrix[i, i+1] = dt

    def _first_detect(self, lanes):
        for l, i in zip(lanes, range(0, self.state_size, 8)):
            self.state[i:i+8:2, 0] = l
        self.kf.statePost = self.state
        self.first_detected = True

    def update(self, lanes):
        if self.first_detected:
            for l, i in zip(lanes, range(0, self.meas_size, 4)):
                if l is not None:
                    self.meas[i:i+4, 0] = l
            self.kf.correct(self.meas)
        else:
            if lanes.count(None) == 0:
                self._first_detect(lanes)

    def predict(self, dt):
        if self.first_detected:
            self._update_dt(dt)
            state = self.kf.predict()
            lanes = []
            for i in range(0, len(state), 8):
                lanes.append((state[i], state[i+2], state[i+4], state[i+6]))
                print(lanes)
            return lanes
        else:
            return None

# %%
def hsv_filter(image, min_val_y, max_val_y,  min_val_w, max_val_w):
    """
    A function returning a mask for pixels within min_val - max_val range
    Inputs:
    - image - a BGR image you want to apply function on
    - min_val_y - array of shape (3,) giving minumum HSV values for yellow color
    - max_val_y - array of shape (3,) giving maximum HSV values for yellow color
    - min_val_w - array of shape (3,) giving minumum HSV values for white color
    - max_val_w - array of shape (3,) giving maximum HSV values for white color
    Returns:
    - img_filtered - image of pixels being in given threshold
    
 gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
 mask = cv2.inRange(frame,lower_color_bounds,upper_color_bounds )
 mask_rgb = cv2.cvtColor(mask,cv2.COLOR_GRAY2BGR)
 frame = frame & mask_rgb

    """
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask_yellow = cv2.inRange(hsv, min_val_y, max_val_y)
    mask_white = cv2.inRange(hsv, min_val_w, max_val_w)
    mask = cv2.bitwise_or(mask_yellow, mask_white)
    img_filtered = cv2.bitwise_and(image, image, mask=mask)
    
    return img_filtered

# %%
class LaneDetector:
    def __init__(self, road_horizon, prob_hough=True):
        self.prob_hough = prob_hough
        self.vote = 50
        self.roi_theta = 0.59
        self.road_horizon = road_horizon

    def _standard_hough(self, img, init_vote):
        # Hough transform wrapper to return a list of points like PHough does
        lines = cv2.HoughLines(img, 1, np.pi/180, init_vote)
        points = [[]]
        for l in lines:
            for rho, theta in l:
                a = np.cos(theta)
                b = np.sin(theta)
                x0 = a*rho
                y0 = b*rho
                x1 = int(x0 + 1000*(-b))
                y1 = int(y0 + 1000*a)
                x2 = int(x0 - 1000*(-b))
                y2 = int(y0 - 1000*a)
                points[0].append((x1, y1, x2, y2))
                print(points)
        return points

    def _base_distance(self, x1, y1, x2, y2, width):
        # compute the point where the give line crosses the base of the frame
        # return distance of that point from center of the frame
        if x2 == x1:
            return (width*0.5) - x1
        m = (y2-y1)/(x2-x1)
        c = y1 - m*x1
        base_cross = -c/m
        return (width*0.5) - base_cross

    def _scale_line(self, x1, y1, x2, y2, frame_height):
        # scale the farthest point of the segment to be on the drawing horizon
        if x1 == x2:
            if y1 < y2:
                y1 = self.road_horizon
                y2 = frame_height
                return x1, y1, x2, y2
            else:
                y2 = self.road_horizon
                y1 = frame_height
                return x1, y1, x2, y2
        if y1 < y2:
            m = (y1-y2)/(x1-x2)
            x1 = ((self.road_horizon-y1)/m) + x1
            y1 = self.road_horizon
            x2 = ((frame_height-y2)/m) + x2
            y2 = frame_height
        else:
            m = (y2-y1)/(x2-x1)
            x2 = ((self.road_horizon-y2)/m) + x2
            y2 = self.road_horizon
            x1 = ((frame_height-y1)/m) + x1
            y1 = frame_height
        return x1, y1, x2, y2

    def detect(self, frame):
        
        img= frame
        
        min_val_y = np.array([15,80,190])
        max_val_y = np.array([30,255,255])
        min_val_w = np.array([0,0,120])
        max_val_w = np.array([255, 255, 255])
        #defining color thresholds
        '''min_val_y = np.array([50,120,130])
        max_val_y = np.array([20,230,230])
        min_val_w = np.array([0,0,150])
        max_val_w = np.array([240,240,240])'''


        roiy_end = frame.shape[0]
        roix_end = frame.shape[1]
        roi = img[self.road_horizon:roiy_end-20, 20:roix_end-20]
        #blur = cv2.medianBlur(roi, 5)
        blur = cv2.bilateralFilter(roi, 9, 21, 21)
        hsv = hsv_filter(blur, min_val_y, max_val_y,  min_val_w, max_val_w)
        cv2.imshow('hsv', hsv)
   

        
        gray = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)
        #roiy_end = frame.shape[0]
        #roix_end = frame.shape[1]
        roi_gray = gray[self.road_horizon:roiy_end-20, 20:roix_end-20]
        blur_gray = cv2.bilateralFilter(gray, 4, 17, 17)#cv2.medianBlur(roi, 11)
        th, thld = cv2.threshold(blur_gray, 130, 255, cv2.THRESH_BINARY)# binary threshold
        cv2.imshow('thld', thld)
        
        contours = cv2.Canny(blur, 60, 120)#canny edges
        cv2.imshow('canny', contours)
        

        
        if self.prob_hough:
            lines = cv2.HoughLinesP(contours, 1, np.pi/180, self.vote, minLineLength=30, maxLineGap=100)
        else:
            lines = self.standard_hough(contours, self.vote)

        if lines is not None:
            # find nearest lines to center
            lines = lines+np.array([0, self.road_horizon, 0, self.road_horizon]).reshape((1, 1, 4))  # scale points from ROI coordinates to full frame coordinates
            left_bound = None
            right_bound = None
            for l in lines:
                # find the rightmost line of the left half of the frame and the leftmost line of the right half
                for x1, y1, x2, y2 in l:
                    theta = np.abs(np.arctan2((y2-y1), (x2-x1)))  # line angle WRT horizon
                    if theta > self.roi_theta:  # ignore lines with a small angle WRT horizon
                        dist = self._base_distance(x1, y1, x2, y2, frame.shape[1])
                        if left_bound is None and dist < 0:
                            left_bound = (x1, y1, x2, y2)
                            left_dist = dist
                        elif right_bound is None and dist > 0:
                            right_bound = (x1, y1, x2, y2)
                            right_dist = dist
                        elif left_bound is not None and 0 > dist > left_dist:
                            left_bound = (x1, y1, x2, y2)
                            left_dist = dist
                        elif right_bound is not None and 0 < dist < right_dist:
                            right_bound = (x1, y1, x2, y2)
                            right_dist = dist
            if left_bound is not None:
                left_bound = self._scale_line(left_bound[0], left_bound[1], left_bound[2], left_bound[3], frame.shape[0])
            if right_bound is not None:
                right_bound = self._scale_line(right_bound[0], right_bound[1], right_bound[2], right_bound[3], frame.shape[0])

            return [left_bound, right_bound]

# %%
def gamma_correction_auto(RGBimage,equalizeHist = False): #0.35
    originalFile = RGBimage.copy()
    red = RGBimage[:,:,2]
    green = RGBimage[:,:,1]
    blue = RGBimage[:,:,0]
    
    forLuminance = cv2.cvtColor(originalFile,cv2.COLOR_BGR2YUV)
    Y = forLuminance[:,:,0]
    totalPix = vidsize[0]* vidsize[1]
    summ = np.sum(Y[:,:])
    Yaverage = np.divide(totalPix,summ)
    #Yclipped = np.clip(Yaverage,0,1)
    epsilon = 1.19209e-007
    correct_param = np.divide(-0.3,np.log10([Yaverage + epsilon]))
    correct_param = 0.7 - correct_param 

    red = red/255.0
    red = cv2.pow(red, correct_param)
    red = np.uint8(red*255)
    if equalizeHist:
        red = cv2.equalizeHist(red)
    
    green = green/255.0
    green = cv2.pow(green, correct_param)
    green = np.uint8(green*255)
    if equalizeHist:
        green = cv2.equalizeHist(green)
        
    
    blue = blue/255.0
    blue = cv2.pow(blue, correct_param)
    blue = np.uint8(blue*255)
    if equalizeHist:
        blue = cv2.equalizeHist(blue)
    

    output = cv2.merge((blue,green,red))
    #print(correct_param)
    return output

# %%
#capturing video
cap = cv2.VideoCapture('C:/Users/DarkLord/Downloads/giscle internship/projects/Lane detection_Giscle/input/videod.mp4')# it will capture videos from camara

vidsize = (640,480,3)

# %%
def region_of_interest(img, vertices):
    # Define a blank matrix that matches the image height/width.
    mask = np.zeros_like(img)
    
    # Retrieve the number of color channels of the image.
    #channel_count = img.shape[2]
    
    # color used to fill polygon
    match_mask_color = 255
      
    # Fill the polygon with white
    cv2.fillPoly(mask, vertices, (255,255,255))
    
    # Returning the image only where mask pixels match
    masked_image = cv2.bitwise_and(img, mask)
    
    return masked_image

# %%
#defining corners for ROI
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)

h1 = int(height)
w1 = int(width)

topLeftPt = (width*(2/5), height*(3.0/5))
topRightPt = (width*(3/5), height*(3.0/5))

region_of_interest_points = [
(0, height),
#(0, height*(4.0/5)),
topLeftPt,
topRightPt,
#(width, height*(4.0/5)),
(width, height),
]

#defining color thresholds
min_val_y = np.array([50, 120, 130])
max_val_y = np.array([20, 230, 230])
min_val_w = np.array([150, 150, 150])
max_val_w = np.array([240, 240, 240])

ticks = 0

lt = LaneTracker(2, 0.1, 1500)
ld = LaneDetector(330)



# Define the codec and create VideoWriter object
#fourcc = cv2.VideoWriter_fourcc(*'XVID')
#out = cv2.VideoWriter('output/result.avi',fourcc, 20.0, (int(cap.get(3)),(int(cap.get(4)))))

while True:
    precTick = ticks
    ticks = cv2.getTickCount()
    dt = (ticks - precTick) / cv2.getTickFrequency()
    ret, frame = cap.read()
    if ret:
        #cv2.imshow('original',frame)
        #gamma = gamma_correction_auto(frame,equalizeHist = False) #0.2
        #cv2.imshow('gamma', gamma)
        #cropped = region_of_interest(frame, np.array([region_of_interest_points], np.int32))
        #cv2.imshow('cropped', cropped)
        #bilateral = cv2.bilateralFilter(cropped, 9, 80, 80)
        #cv2.imshow('bilateral', bilateral)
        #hsv = hsv_filter(cropped, min_val_y, max_val_y,  min_val_w, max_val_w)
        print(h1,w1)   
        predicted = lt.predict(dt)

        lanes = ld.detect(frame)
        
        if predicted is not None:
            cv2.line(frame, (predicted[0][0], predicted[0][1]), (predicted[0][2], predicted[0][3]), (0, 0, 255), 2)
            cv2.line(frame, (predicted[1][0], predicted[1][1]), (predicted[1][2], predicted[1][3]), (0, 0, 255), 2)
           
        lt.update(lanes)
        
        #cv2.imshow('hsv', hsv)
        #canny = cv2.Canny(hsv, 80, 255) #100
        #cv2.imshow('canny', canny)
        #hough, lines = hough_transform(frame, canny, 11, discard_horizontal = 0.7) #14 0.4
        #cv2.imshow('hough', hough)
        #_, frame = cap.read()
        #final = clustering(lines, frame, np.array([region_of_interest_points], np.int32), eps = 0.5, min_samples = 4)
        
       
        #out.write(frame)# write frames in the disk
        final = cv2.rectangle(frame,(20,315),(w1-20,h1),(0,255,0),2)
        cv2.imshow('final', final)
        

        
        k = cv2.waitKey(29) & 0xFF
        if k == ord('q'):
            break
            
cap.release()
#out.release()
cv2.destroyAllWindows()
# Out:
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# [(array([ 78.16000366], dtype=float32), array([ 480.], dtype=float32), array([ 270.16000366], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 78.16000366], dtype=float32), array([ 480.], dtype=float32), array([ 270.16000366], dtype=float32), array([ 330.], dtype=float32)), (array([ 331.], dtype=float32), array([ 330.], dtype=float32), array([ 553.05883789], dtype=float32), array([ 480.], dtype=float32))]
# 480 640
# [(array([ 78.15997314], dtype=float32), array([ 480.], dtype=float32), array([ 270.16000366], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 78.15997314], dtype=float32), array([ 480.], dtype=float32), array([ 270.16000366], dtype=float32), array([ 330.], dtype=float32)), (array([ 330.9927063], dtype=float32), array([ 329.99276733], dtype=float32), array([ 553.04669189], dtype=float32), array([ 479.98944092], dtype=float32))]
# 480 640
# [(array([ 78.15969849], dtype=float32), array([ 480.], dtype=float32), array([ 270.15975952], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 78.15969849], dtype=float32), array([ 480.], dtype=float32), array([ 270.15975952], dtype=float32), array([ 330.], dtype=float32)), (array([ 330.97198486], dtype=float32), array([ 329.97210693], dtype=float32), array([ 553.01202393], dtype=float32), array([ 479.9593811], dtype=float32))]
# 480 640
# [(array([ 78.15842438], dtype=float32), array([ 480.], dtype=float32), array([ 270.15927124], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 78.15842438], dtype=float32), array([ 480.], dtype=float32), array([ 270.15927124], dtype=float32), array([ 330.], dtype=float32)), (array([ 330.96759033], dtype=float32), array([ 329.96697998], dtype=float32), array([ 553.00421143], dtype=float32), array([ 479.9519043], dtype=float32))]
# 480 640
# [(array([ 78.15567017], dtype=float32), array([ 480.], dtype=float32), array([ 270.15777588], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 78.15567017], dtype=float32), array([ 480.], dtype=float32), array([ 270.15777588], dtype=float32), array([ 330.], dtype=float32)), (array([ 330.96411133], dtype=float32), array([ 329.9621582], dtype=float32), array([ 552.99755859], dtype=float32), array([ 479.94488525], dtype=float32))]
# 480 640
# [(array([ 78.14944458], dtype=float32), array([ 480.], dtype=float32), array([ 270.15402222], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 78.14944458], dtype=float32), array([ 480.], dtype=float32), array([ 270.15402222], dtype=float32), array([ 330.], dtype=float32)), (array([ 330.95925903], dtype=float32), array([ 329.95501709], dtype=float32), array([ 552.98809814], dtype=float32), array([ 479.93447876], dtype=float32))]
# 480 640
# [(array([ 78.13566589], dtype=float32), array([ 480.], dtype=float32), array([ 270.14654541], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 78.13566589], dtype=float32), array([ 480.], dtype=float32), array([ 270.14654541], dtype=float32), array([ 330.], dtype=float32)), (array([ 330.9569397], dtype=float32), array([ 329.94921875], dtype=float32), array([ 552.98217773], dtype=float32), array([ 479.92602539], dtype=float32))]
# 480 640
# [(array([ 78.11140442], dtype=float32), array([ 480.], dtype=float32), array([ 270.1317749], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 78.11140442], dtype=float32), array([ 480.], dtype=float32), array([ 270.1317749], dtype=float32), array([ 330.], dtype=float32)), (array([ 330.95629883], dtype=float32), array([ 329.94363403], dtype=float32), array([ 552.97821045], dtype=float32), array([ 479.91790771], dtype=float32))]
# 480 640
# [(array([ 78.07174683], dtype=float32), array([ 480.], dtype=float32), array([ 270.10559082], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 78.07174683], dtype=float32), array([ 480.], dtype=float32), array([ 270.10559082], dtype=float32), array([ 330.], dtype=float32)), (array([ 330.95724487], dtype=float32), array([ 329.93774414], dtype=float32), array([ 552.97576904], dtype=float32), array([ 479.90936279], dtype=float32))]
# 480 640
# [(array([ 78.00987244], dtype=float32), array([ 480.], dtype=float32), array([ 270.06222534], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 78.00987244], dtype=float32), array([ 480.], dtype=float32), array([ 270.06222534], dtype=float32), array([ 330.], dtype=float32)), (array([ 330.96029663], dtype=float32), array([ 329.93154907], dtype=float32), array([ 552.97540283], dtype=float32), array([ 479.90039062], dtype=float32))]
# 480 640
# [(array([ 77.92199707], dtype=float32), array([ 480.], dtype=float32), array([ 269.99981689], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 77.92199707], dtype=float32), array([ 480.], dtype=float32), array([ 269.99981689], dtype=float32), array([ 330.], dtype=float32)), (array([ 330.96603394], dtype=float32), array([ 329.92486572], dtype=float32), array([ 552.97766113], dtype=float32), array([ 479.89065552], dtype=float32))]
# 480 640
# [(array([ 77.81988525], dtype=float32), array([ 480.], dtype=float32), array([ 269.92996216], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 77.81988525], dtype=float32), array([ 480.], dtype=float32), array([ 269.92996216], dtype=float32), array([ 330.], dtype=float32)), (array([ 330.97555542], dtype=float32), array([ 329.91903687], dtype=float32), array([ 552.98455811], dtype=float32), array([ 479.88217163], dtype=float32))]
# 480 640
# [(array([ 77.71658325], dtype=float32), array([ 480.], dtype=float32), array([ 269.86349487], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 77.71658325], dtype=float32), array([ 480.], dtype=float32), array([ 269.86349487], dtype=float32), array([ 330.], dtype=float32)), (array([ 330.98876953], dtype=float32), array([ 329.91421509], dtype=float32), array([ 552.99603271], dtype=float32), array([ 479.87512207], dtype=float32))]
# 480 640
# [(array([ 77.58798218], dtype=float32), array([ 480.], dtype=float32), array([ 269.7956543], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 77.58798218], dtype=float32), array([ 480.], dtype=float32), array([ 269.7956543], dtype=float32), array([ 330.], dtype=float32)), (array([ 331.00543213], dtype=float32), array([ 329.909729], dtype=float32), array([ 553.01141357], dtype=float32), array([ 479.86859131], dtype=float32))]
# 480 640
# [(array([ 77.4310379], dtype=float32), array([ 480.], dtype=float32), array([ 269.71298218], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 77.4310379], dtype=float32), array([ 480.], dtype=float32), array([ 269.71298218], dtype=float32), array([ 330.], dtype=float32)), (array([ 331.06463623], dtype=float32), array([ 329.90411377], dtype=float32), array([ 553.04498291], dtype=float32), array([ 479.86047363], dtype=float32))]
# 480 640
# [(array([ 77.26319885], dtype=float32), array([ 480.], dtype=float32), array([ 269.63336182], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 77.26319885], dtype=float32), array([ 480.], dtype=float32), array([ 269.63336182], dtype=float32), array([ 330.], dtype=float32)), (array([ 331.13684082], dtype=float32), array([ 329.89971924], dtype=float32), array([ 553.08703613], dtype=float32), array([ 479.85409546], dtype=float32))]
# 480 640
# [(array([ 77.0775528], dtype=float32), array([ 480.], dtype=float32), array([ 269.55554199], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 77.0775528], dtype=float32), array([ 480.], dtype=float32), array([ 269.55554199], dtype=float32), array([ 330.], dtype=float32)), (array([ 331.22360229], dtype=float32), array([ 329.89508057], dtype=float32), array([ 553.13781738], dtype=float32), array([ 479.84732056], dtype=float32))]
# 480 640
# [(array([ 76.89295197], dtype=float32), array([ 480.], dtype=float32), array([ 269.49209595], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 76.89295197], dtype=float32), array([ 480.], dtype=float32), array([ 269.49209595], dtype=float32), array([ 330.], dtype=float32)), (array([ 331.32608032], dtype=float32), array([ 329.89056396], dtype=float32), array([ 553.19818115], dtype=float32), array([ 479.84072876], dtype=float32))]
# 480 640
# [(array([ 76.70220947], dtype=float32), array([ 480.], dtype=float32), array([ 269.47512817], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 76.70220947], dtype=float32), array([ 480.], dtype=float32), array([ 269.47512817], dtype=float32), array([ 330.], dtype=float32)), (array([ 331.4463501], dtype=float32), array([ 329.88598633], dtype=float32), array([ 553.26940918], dtype=float32), array([ 479.83407593], dtype=float32))]
# 480 640
# [(array([ 76.5038147], dtype=float32), array([ 480.], dtype=float32), array([ 269.49789429], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 76.5038147], dtype=float32), array([ 480.], dtype=float32), array([ 269.49789429], dtype=float32), array([ 330.], dtype=float32)), (array([ 331.59399414], dtype=float32), array([ 329.88027954], dtype=float32), array([ 553.35681152], dtype=float32), array([ 479.82580566], dtype=float32))]
# 480 640
# [(array([ 76.32868958], dtype=float32), array([ 480.], dtype=float32), array([ 269.57485962], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 76.32868958], dtype=float32), array([ 480.], dtype=float32), array([ 269.57485962], dtype=float32), array([ 330.], dtype=float32)), (array([ 331.7678833], dtype=float32), array([ 329.87466431], dtype=float32), array([ 553.46026611], dtype=float32), array([ 479.81765747], dtype=float32))]
# 480 640
# [(array([ 76.14917755], dtype=float32), array([ 480.], dtype=float32), array([ 269.67965698], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 76.14917755], dtype=float32), array([ 480.], dtype=float32), array([ 269.67965698], dtype=float32), array([ 330.], dtype=float32)), (array([ 331.96514893], dtype=float32), array([ 329.86972046], dtype=float32), array([ 553.57824707], dtype=float32), array([ 479.81048584], dtype=float32))]
# 480 640
# [(array([ 75.95319366], dtype=float32), array([ 480.], dtype=float32), array([ 269.8097229], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 75.95319366], dtype=float32), array([ 480.], dtype=float32), array([ 269.8097229], dtype=float32), array([ 330.], dtype=float32)), (array([ 331.87234497], dtype=float32), array([ 329.86480713], dtype=float32), array([ 553.28259277], dtype=float32), array([ 479.80337524], dtype=float32))]
# 480 640
# [(array([ 75.74942017], dtype=float32), array([ 480.], dtype=float32), array([ 269.96813965], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 75.74942017], dtype=float32), array([ 480.], dtype=float32), array([ 269.96813965], dtype=float32), array([ 330.], dtype=float32)), (array([ 331.79162598], dtype=float32), array([ 329.86044312], dtype=float32), array([ 552.82879639], dtype=float32), array([ 479.79702759], dtype=float32))]
# 480 640
# [(array([ 75.55195618], dtype=float32), array([ 480.], dtype=float32), array([ 270.15338135], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 75.55195618], dtype=float32), array([ 480.], dtype=float32), array([ 270.15338135], dtype=float32), array([ 330.], dtype=float32)), (array([ 331.68423462], dtype=float32), array([ 329.85717773], dtype=float32), array([ 552.30554199], dtype=float32), array([ 479.79229736], dtype=float32))]
# 480 640
# [(array([ 75.31291962], dtype=float32), array([ 480.], dtype=float32), array([ 270.36685181], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 75.31291962], dtype=float32), array([ 480.], dtype=float32), array([ 270.36685181], dtype=float32), array([ 330.], dtype=float32)), (array([ 331.56411743], dtype=float32), array([ 329.85293579], dtype=float32), array([ 551.70050049], dtype=float32), array([ 479.78610229], dtype=float32))]
# 480 640
# [(array([ 75.07055664], dtype=float32), array([ 480.], dtype=float32), array([ 270.61019897], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 75.07055664], dtype=float32), array([ 480.], dtype=float32), array([ 270.61019897], dtype=float32), array([ 330.], dtype=float32)), (array([ 331.24639893], dtype=float32), array([ 329.84942627], dtype=float32), array([ 550.92376709], dtype=float32), array([ 479.78103638], dtype=float32))]
# 480 640
# [(array([ 74.83364105], dtype=float32), array([ 480.], dtype=float32), array([ 270.87808228], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 74.83364105], dtype=float32), array([ 480.], dtype=float32), array([ 270.87808228], dtype=float32), array([ 330.], dtype=float32)), (array([ 330.88357544], dtype=float32), array([ 329.84695435], dtype=float32), array([ 550.07220459], dtype=float32), array([ 479.7774353], dtype=float32))]
# 480 640
# [(array([ 74.59146118], dtype=float32), array([ 480.], dtype=float32), array([ 271.16934204], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 74.59146118], dtype=float32), array([ 480.], dtype=float32), array([ 271.16934204], dtype=float32), array([ 330.], dtype=float32)), (array([ 330.48239136], dtype=float32), array([ 329.8449707], dtype=float32), array([ 549.14819336], dtype=float32), array([ 479.77456665], dtype=float32))]
# 480 640
# [(array([ 74.34681702], dtype=float32), array([ 480.], dtype=float32), array([ 271.48117065], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 74.34681702], dtype=float32), array([ 480.], dtype=float32), array([ 271.48117065], dtype=float32), array([ 330.], dtype=float32)), (array([ 330.04653931], dtype=float32), array([ 329.84350586], dtype=float32), array([ 548.16070557], dtype=float32), array([ 479.77246094], dtype=float32))]
# 480 640
# [(array([ 74.08881378], dtype=float32), array([ 480.], dtype=float32), array([ 271.81689453], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 74.08881378], dtype=float32), array([ 480.], dtype=float32), array([ 271.81689453], dtype=float32), array([ 330.], dtype=float32)), (array([ 329.57492065], dtype=float32), array([ 329.8421936], dtype=float32), array([ 547.09814453], dtype=float32), array([ 479.77053833], dtype=float32))]
# 480 640
# [(array([ 73.81964111], dtype=float32), array([ 480.], dtype=float32), array([ 272.17614746], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 73.81964111], dtype=float32), array([ 480.], dtype=float32), array([ 272.17614746], dtype=float32), array([ 330.], dtype=float32)), (array([ 329.06723022], dtype=float32), array([ 329.84109497], dtype=float32), array([ 545.96203613], dtype=float32), array([ 479.7689209], dtype=float32))]
# 480 640
# [(array([ 73.55904388], dtype=float32), array([ 480.], dtype=float32), array([ 272.54675293], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 73.55904388], dtype=float32), array([ 480.], dtype=float32), array([ 272.54675293], dtype=float32), array([ 330.], dtype=float32)), (array([ 328.69400024], dtype=float32), array([ 329.84072876], dtype=float32), array([ 544.15350342], dtype=float32), array([ 479.7684021], dtype=float32))]
# 480 640
# [(array([ 73.26727295], dtype=float32), array([ 480.], dtype=float32), array([ 272.95153809], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 73.26727295], dtype=float32), array([ 480.], dtype=float32), array([ 272.95153809], dtype=float32), array([ 330.], dtype=float32)), (array([ 328.16720581], dtype=float32), array([ 329.83999634], dtype=float32), array([ 542.42004395], dtype=float32), array([ 479.7673645], dtype=float32))]
# 480 640
# [(array([ 72.95646667], dtype=float32), array([ 480.], dtype=float32), array([ 273.38632202], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 72.95646667], dtype=float32), array([ 480.], dtype=float32), array([ 273.38632202], dtype=float32), array([ 330.], dtype=float32)), (array([ 327.72717285], dtype=float32), array([ 329.83935547], dtype=float32), array([ 540.3104248], dtype=float32), array([ 479.76638794], dtype=float32))]
# 480 640
# [(array([ 72.63424683], dtype=float32), array([ 480.], dtype=float32), array([ 273.84683228], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 72.63424683], dtype=float32), array([ 480.], dtype=float32), array([ 273.84683228], dtype=float32), array([ 330.], dtype=float32)), (array([ 327.13977051], dtype=float32), array([ 329.83898926], dtype=float32), array([ 538.48657227], dtype=float32), array([ 479.76583862], dtype=float32))]
# 480 640
# [(array([ 72.30528259], dtype=float32), array([ 480.], dtype=float32), array([ 274.32922363], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 72.30528259], dtype=float32), array([ 480.], dtype=float32), array([ 274.32922363], dtype=float32), array([ 330.], dtype=float32)), (array([ 326.52627563], dtype=float32), array([ 329.83898926], dtype=float32), array([ 536.12805176], dtype=float32), array([ 479.76583862], dtype=float32))]
# 480 640
# [(array([ 71.99930573], dtype=float32), array([ 480.], dtype=float32), array([ 274.80682373], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 71.99930573], dtype=float32), array([ 480.], dtype=float32), array([ 274.80682373], dtype=float32), array([ 330.], dtype=float32)), (array([ 325.88735962], dtype=float32), array([ 329.83987427], dtype=float32), array([ 533.73260498], dtype=float32), array([ 479.76715088], dtype=float32))]
# 480 640
# [(array([ 71.68928528], dtype=float32), array([ 480.], dtype=float32), array([ 275.29858398], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 71.68928528], dtype=float32), array([ 480.], dtype=float32), array([ 275.29858398], dtype=float32), array([ 330.], dtype=float32)), (array([ 325.22720337], dtype=float32), array([ 329.84103394], dtype=float32), array([ 531.25665283], dtype=float32), array([ 479.76879883], dtype=float32))]
# 480 640
# [(array([ 71.38114929], dtype=float32), array([ 480.], dtype=float32), array([ 275.79830933], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 71.38114929], dtype=float32), array([ 480.], dtype=float32), array([ 275.79830933], dtype=float32), array([ 330.], dtype=float32)), (array([ 324.52871704], dtype=float32), array([ 329.84249878], dtype=float32), array([ 528.56304932], dtype=float32), array([ 479.77096558], dtype=float32))]
# 480 640
# [(array([ 71.03878021], dtype=float32), array([ 480.], dtype=float32), array([ 276.34030151], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 71.03878021], dtype=float32), array([ 480.], dtype=float32), array([ 276.34030151], dtype=float32), array([ 330.], dtype=float32)), (array([ 323.77563477], dtype=float32), array([ 329.84375], dtype=float32), array([ 525.66223145], dtype=float32), array([ 479.77276611], dtype=float32))]
# 480 640
# [(array([ 70.67618561], dtype=float32), array([ 480.], dtype=float32), array([ 276.91415405], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 70.67618561], dtype=float32), array([ 480.], dtype=float32), array([ 276.91415405], dtype=float32), array([ 330.], dtype=float32)), (array([ 322.97833252], dtype=float32), array([ 329.84506226], dtype=float32), array([ 522.59112549], dtype=float32), array([ 479.7746582], dtype=float32))]
# 480 640
# [(array([ 70.35509491], dtype=float32), array([ 480.], dtype=float32), array([ 277.45608521], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 70.35509491], dtype=float32), array([ 480.], dtype=float32), array([ 277.45608521], dtype=float32), array([ 330.], dtype=float32)), (array([ 322.21356201], dtype=float32), array([ 329.84725952], dtype=float32), array([ 519.63641357], dtype=float32), array([ 479.77786255], dtype=float32))]
# 480 640
# [(array([ 69.99726868], dtype=float32), array([ 480.], dtype=float32), array([ 278.04501343], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 69.99726868], dtype=float32), array([ 480.], dtype=float32), array([ 278.04501343], dtype=float32), array([ 330.], dtype=float32)), (array([ 321.38745117], dtype=float32), array([ 329.84924316], dtype=float32), array([ 516.44836426], dtype=float32), array([ 479.78076172], dtype=float32))]
# 480 640
# [(array([ 69.6812439], dtype=float32), array([ 480.], dtype=float32), array([ 278.59658813], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 69.6812439], dtype=float32), array([ 480.], dtype=float32), array([ 278.59658813], dtype=float32), array([ 330.], dtype=float32)), (array([ 320.6031189], dtype=float32), array([ 329.85198975], dtype=float32), array([ 513.41363525], dtype=float32), array([ 479.78475952], dtype=float32))]
# 480 640
# [(array([ 69.38200378], dtype=float32), array([ 480.], dtype=float32), array([ 279.13391113], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 69.38200378], dtype=float32), array([ 480.], dtype=float32), array([ 279.13391113], dtype=float32), array([ 330.], dtype=float32)), (array([ 319.83422852], dtype=float32), array([ 329.8550415], dtype=float32), array([ 510.43518066], dtype=float32), array([ 479.78921509], dtype=float32))]
# 480 640
# [(array([ 69.07408905], dtype=float32), array([ 480.], dtype=float32), array([ 279.68478394], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 69.07408905], dtype=float32), array([ 480.], dtype=float32), array([ 279.68478394], dtype=float32), array([ 330.], dtype=float32)), (array([ 319.04656982], dtype=float32), array([ 329.85812378], dtype=float32), array([ 507.38446045], dtype=float32), array([ 479.79367065], dtype=float32))]
# 480 640
# [(array([ 68.77729034], dtype=float32), array([ 480.], dtype=float32), array([ 280.22607422], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 68.77729034], dtype=float32), array([ 480.], dtype=float32), array([ 280.22607422], dtype=float32), array([ 330.], dtype=float32)), (array([ 318.2694397], dtype=float32), array([ 329.86141968], dtype=float32), array([ 504.37210083], dtype=float32), array([ 479.79846191], dtype=float32))]
# 480 640
# [(array([ 68.47486115], dtype=float32), array([ 480.], dtype=float32), array([ 280.77709961], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 68.47486115], dtype=float32), array([ 480.], dtype=float32), array([ 280.77709961], dtype=float32), array([ 330.], dtype=float32)), (array([ 317.47851562], dtype=float32), array([ 329.86477661], dtype=float32), array([ 501.30651855], dtype=float32), array([ 479.80331421], dtype=float32))]
# 480 640
# [(array([ 68.19706726], dtype=float32), array([ 480.], dtype=float32), array([ 281.30032349], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 68.19706726], dtype=float32), array([ 480.], dtype=float32), array([ 281.30032349], dtype=float32), array([ 330.], dtype=float32)), (array([ 316.72232056], dtype=float32), array([ 329.86837769], dtype=float32), array([ 498.37161255], dtype=float32), array([ 479.80856323], dtype=float32))]
# 480 640
# [(array([ 67.92690277], dtype=float32), array([ 480.], dtype=float32), array([ 281.81512451], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 67.92690277], dtype=float32), array([ 480.], dtype=float32), array([ 281.81512451], dtype=float32), array([ 330.], dtype=float32)), (array([ 315.97650146], dtype=float32), array([ 329.87207031], dtype=float32), array([ 495.47579956], dtype=float32), array([ 479.81390381], dtype=float32))]
# 480 640
# [(array([ 67.64807129], dtype=float32), array([ 480.], dtype=float32), array([ 282.34207153], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 67.64807129], dtype=float32), array([ 480.], dtype=float32), array([ 282.34207153], dtype=float32), array([ 330.], dtype=float32)), (array([ 315.21435547], dtype=float32), array([ 329.87573242], dtype=float32), array([ 492.51754761], dtype=float32), array([ 479.81921387], dtype=float32))]
# 480 640
# [(array([ 67.38861847], dtype=float32), array([ 480.], dtype=float32), array([ 282.84500122], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 67.38861847], dtype=float32), array([ 480.], dtype=float32), array([ 282.84500122], dtype=float32), array([ 330.], dtype=float32)), (array([ 302.57357788], dtype=float32), array([ 329.8795166], dtype=float32), array([ 479.7522583], dtype=float32), array([ 479.82473755], dtype=float32))]
# 480 640
# [(array([ 67.14582062], dtype=float32), array([ 480.], dtype=float32), array([ 283.32617188], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 67.14582062], dtype=float32), array([ 480.], dtype=float32), array([ 283.32617188], dtype=float32), array([ 330.], dtype=float32)), (array([ 289.97525024], dtype=float32), array([ 329.88342285], dtype=float32), array([ 467.10772705], dtype=float32), array([ 479.8303833], dtype=float32))]
# 480 640
# [(array([ 66.90936279], dtype=float32), array([ 480.], dtype=float32), array([ 283.7984314], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 66.90936279], dtype=float32), array([ 480.], dtype=float32), array([ 283.7984314], dtype=float32), array([ 330.], dtype=float32)), (array([ 277.4369812], dtype=float32), array([ 329.8873291], dtype=float32), array([ 454.54907227], dtype=float32), array([ 479.83602905], dtype=float32))]
# 480 640
# [(array([ 66.6689682], dtype=float32), array([ 480.], dtype=float32), array([ 284.27566528], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 66.6689682], dtype=float32), array([ 480.], dtype=float32), array([ 284.27566528], dtype=float32), array([ 330.], dtype=float32)), (array([ 264.90045166], dtype=float32), array([ 329.89120483], dtype=float32), array([ 441.9725647], dtype=float32), array([ 479.8416748], dtype=float32))]
# 480 640
# [(array([ 66.41358948], dtype=float32), array([ 480.], dtype=float32), array([ 284.77377319], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 66.41358948], dtype=float32), array([ 480.], dtype=float32), array([ 284.77377319], dtype=float32), array([ 330.], dtype=float32)), (array([ 252.23384094], dtype=float32), array([ 329.89505005], dtype=float32), array([ 429.20391846], dtype=float32), array([ 479.84725952], dtype=float32))]
# 480 640
# [(array([ 66.1882019], dtype=float32), array([ 480.], dtype=float32), array([ 285.23062134], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 66.1882019], dtype=float32), array([ 480.], dtype=float32), array([ 285.23062134], dtype=float32), array([ 330.], dtype=float32)), (array([ 239.79072571], dtype=float32), array([ 329.8989563], dtype=float32), array([ 416.78637695], dtype=float32), array([ 479.85296631], dtype=float32))]
# 480 640
# [(array([ 65.98462677], dtype=float32), array([ 480.], dtype=float32), array([ 285.65606689], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 65.98462677], dtype=float32), array([ 480.], dtype=float32), array([ 285.65606689], dtype=float32), array([ 330.], dtype=float32)), (array([ 227.61112976], dtype=float32), array([ 329.90292358], dtype=float32), array([ 404.7159729], dtype=float32), array([ 479.85870361], dtype=float32))]
# 480 640
# [(array([ 65.79238129], dtype=float32), array([ 480.], dtype=float32), array([ 286.06411743], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 65.79238129], dtype=float32), array([ 480.], dtype=float32), array([ 286.06411743], dtype=float32), array([ 330.], dtype=float32)), (array([ 215.64959717], dtype=float32), array([ 329.90682983], dtype=float32), array([ 392.89959717], dtype=float32), array([ 479.8644104], dtype=float32))]
# 480 640
# [(array([ 65.61277008], dtype=float32), array([ 480.], dtype=float32), array([ 286.45245361], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 65.61277008], dtype=float32), array([ 480.], dtype=float32), array([ 286.45245361], dtype=float32), array([ 330.], dtype=float32)), (array([ 203.9523468], dtype=float32), array([ 329.91070557], dtype=float32), array([ 381.38568115], dtype=float32), array([ 479.87005615], dtype=float32))]
# 480 640
# [(array([ 65.45561981], dtype=float32), array([ 480.], dtype=float32), array([ 286.8062439], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 65.45561981], dtype=float32), array([ 480.], dtype=float32), array([ 286.8062439], dtype=float32), array([ 330.], dtype=float32)), (array([ 192.69154358], dtype=float32), array([ 329.91452026], dtype=float32), array([ 370.37918091], dtype=float32), array([ 479.87564087], dtype=float32))]
# 480 640
# [(array([ 65.28098297], dtype=float32), array([ 480.], dtype=float32), array([ 287.18371582], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 65.28098297], dtype=float32), array([ 480.], dtype=float32), array([ 287.18371582], dtype=float32), array([ 330.], dtype=float32)), (array([ 181.32611084], dtype=float32), array([ 329.91830444], dtype=float32), array([ 359.19128418], dtype=float32), array([ 479.88113403], dtype=float32))]
# 480 640
# [(array([ 65.10520935], dtype=float32), array([ 480.], dtype=float32), array([ 287.56170654], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 65.10520935], dtype=float32), array([ 480.], dtype=float32), array([ 287.56170654], dtype=float32), array([ 330.], dtype=float32)), (array([ 170.02972412], dtype=float32), array([ 329.92205811], dtype=float32), array([ 348.06048584], dtype=float32), array([ 479.88656616], dtype=float32))]
# 480 640
# [(array([ 64.96218872], dtype=float32), array([ 480.], dtype=float32), array([ 287.8894043], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 64.96218872], dtype=float32), array([ 480.], dtype=float32), array([ 287.8894043], dtype=float32), array([ 330.], dtype=float32)), (array([ 159.36177063], dtype=float32), array([ 329.92572021], dtype=float32), array([ 337.662323], dtype=float32), array([ 479.89190674], dtype=float32))]
# 480 640
# [(array([ 64.84124756], dtype=float32), array([ 480.], dtype=float32), array([ 288.18161011], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 64.84124756], dtype=float32), array([ 480.], dtype=float32), array([ 288.18161011], dtype=float32), array([ 330.], dtype=float32)), (array([ 149.23158264], dtype=float32), array([ 329.92929077], dtype=float32), array([ 327.86175537], dtype=float32), array([ 479.89709473], dtype=float32))]
# 480 640
# [(array([ 64.70050049], dtype=float32), array([ 480.], dtype=float32), array([ 288.50180054], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 64.70050049], dtype=float32), array([ 480.], dtype=float32), array([ 288.50180054], dtype=float32), array([ 330.], dtype=float32)), (array([ 138.90023804], dtype=float32), array([ 329.93283081], dtype=float32), array([ 317.78067017], dtype=float32), array([ 479.90222168], dtype=float32))]
# 480 640
# [(array([ 64.58248901], dtype=float32), array([ 480.], dtype=float32), array([ 288.78546143], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 64.58248901], dtype=float32), array([ 480.], dtype=float32), array([ 288.78546143], dtype=float32), array([ 330.], dtype=float32)), (array([ 129.1231842], dtype=float32), array([ 329.9362793], dtype=float32), array([ 308.31539917], dtype=float32), array([ 479.90722656], dtype=float32))]
# 480 640
# [(array([ 64.45140839], dtype=float32), array([ 480.], dtype=float32), array([ 289.08755493], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 64.45140839], dtype=float32), array([ 480.], dtype=float32), array([ 289.08755493], dtype=float32), array([ 330.], dtype=float32)), (array([ 119.21638489], dtype=float32), array([ 329.93969727], dtype=float32), array([ 298.66769409], dtype=float32), array([ 479.91220093], dtype=float32))]
# 480 640
# [(array([ 64.34703064], dtype=float32), array([ 480.], dtype=float32), array([ 289.34655762], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 64.34703064], dtype=float32), array([ 480.], dtype=float32), array([ 289.34655762], dtype=float32), array([ 330.], dtype=float32)), (array([ 109.97518158], dtype=float32), array([ 329.94299316], dtype=float32), array([ 289.7565918], dtype=float32), array([ 479.91699219], dtype=float32))]
# 480 640
# [(array([ 64.24395752], dtype=float32), array([ 480.], dtype=float32), array([ 289.60159302], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 64.24395752], dtype=float32), array([ 480.], dtype=float32), array([ 289.60159302], dtype=float32), array([ 330.], dtype=float32)), (array([ 100.90007782], dtype=float32), array([ 329.94622803], dtype=float32), array([ 281.00283813], dtype=float32), array([ 479.92169189], dtype=float32))]
# 480 640
# [(array([ 64.1396637], dtype=float32), array([ 480.], dtype=float32), array([ 289.85693359], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 64.1396637], dtype=float32), array([ 480.], dtype=float32), array([ 289.85693359], dtype=float32), array([ 330.], dtype=float32)), (array([ 91.91857147], dtype=float32), array([ 329.94940186], dtype=float32), array([ 272.32806396], dtype=float32), array([ 479.92633057], dtype=float32))]
# 480 640
# [(array([ 64.04657745], dtype=float32), array([ 480.], dtype=float32), array([ 290.09295654], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 64.04657745], dtype=float32), array([ 480.], dtype=float32), array([ 290.09295654], dtype=float32), array([ 330.], dtype=float32)), (array([ 83.30730438], dtype=float32), array([ 329.95248413], dtype=float32), array([ 264.04501343], dtype=float32), array([ 479.93084717], dtype=float32))]
# 480 640
# [(array([ 63.95644379], dtype=float32), array([ 480.], dtype=float32), array([ 290.32269287], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.95644379], dtype=float32), array([ 480.], dtype=float32), array([ 290.32269287], dtype=float32), array([ 330.], dtype=float32)), (array([ 74.88019562], dtype=float32), array([ 329.95550537], dtype=float32), array([ 255.94384766], dtype=float32), array([ 479.93527222], dtype=float32))]
# 480 640
# [(array([ 63.89258575], dtype=float32), array([ 480.], dtype=float32), array([ 290.50845337], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.89258575], dtype=float32), array([ 480.], dtype=float32), array([ 290.50845337], dtype=float32), array([ 330.], dtype=float32)), (array([ 67.22322083], dtype=float32), array([ 329.95837402], dtype=float32), array([ 248.67207336], dtype=float32), array([ 479.93945312], dtype=float32))]
# 480 640
# [(array([ 63.83209229], dtype=float32), array([ 480.], dtype=float32), array([ 290.68673706], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.83209229], dtype=float32), array([ 480.], dtype=float32), array([ 290.68673706], dtype=float32), array([ 330.], dtype=float32)), (array([ 59.79825592], dtype=float32), array([ 329.96115112], dtype=float32), array([ 241.62768555], dtype=float32), array([ 479.94348145], dtype=float32))]
# 480 640
# [(array([ 63.7428627], dtype=float32), array([ 480.], dtype=float32), array([ 290.91033936], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.7428627], dtype=float32), array([ 480.], dtype=float32), array([ 290.91033936], dtype=float32), array([ 330.], dtype=float32)), (array([ 51.73637009], dtype=float32), array([ 329.96401978], dtype=float32), array([ 233.86279297], dtype=float32), array([ 479.94766235], dtype=float32))]
# 480 640
# [(array([ 63.679245], dtype=float32), array([ 480.], dtype=float32), array([ 291.09085083], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.679245], dtype=float32), array([ 480.], dtype=float32), array([ 291.09085083], dtype=float32), array([ 330.], dtype=float32)), (array([ 44.44099426], dtype=float32), array([ 329.96670532], dtype=float32), array([ 226.92074585], dtype=float32), array([ 479.95162964], dtype=float32))]
# 480 640
# [(array([ 63.61996078], dtype=float32), array([ 480.], dtype=float32), array([ 291.26278687], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.61996078], dtype=float32), array([ 480.], dtype=float32), array([ 291.26278687], dtype=float32), array([ 330.], dtype=float32)), (array([ 37.36819077], dtype=float32), array([ 329.96936035], dtype=float32), array([ 220.20228577], dtype=float32), array([ 479.95547485], dtype=float32))]
# 480 640
# [(array([ 63.58006668], dtype=float32), array([ 480.], dtype=float32), array([ 291.40106201], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.58006668], dtype=float32), array([ 480.], dtype=float32), array([ 291.40106201], dtype=float32), array([ 330.], dtype=float32)), (array([ 30.95310593], dtype=float32), array([ 329.97183228], dtype=float32), array([ 214.17710876], dtype=float32), array([ 479.95910645], dtype=float32))]
# 480 640
# [(array([ 63.53785324], dtype=float32), array([ 480.], dtype=float32), array([ 291.54156494], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.53785324], dtype=float32), array([ 480.], dtype=float32), array([ 291.54156494], dtype=float32), array([ 330.], dtype=float32)), (array([ 24.59142876], dtype=float32), array([ 329.97427368], dtype=float32), array([ 208.18899536], dtype=float32), array([ 479.96264648], dtype=float32))]
# 480 640
# [(array([ 63.48341751], dtype=float32), array([ 480.], dtype=float32), array([ 291.70126343], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.48341751], dtype=float32), array([ 480.], dtype=float32), array([ 291.70126343], dtype=float32), array([ 330.], dtype=float32)), (array([ 17.9636116], dtype=float32), array([ 329.97674561], dtype=float32), array([ 201.89877319], dtype=float32), array([ 479.96624756], dtype=float32))]
# 480 640
# [(array([ 63.48608398], dtype=float32), array([ 480.], dtype=float32), array([ 291.76312256], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.48608398], dtype=float32), array([ 480.], dtype=float32), array([ 291.76312256], dtype=float32), array([ 330.], dtype=float32)), (array([ 13.1753521], dtype=float32), array([ 329.97879028], dtype=float32), array([ 197.5617218], dtype=float32), array([ 479.96923828], dtype=float32))]
# 480 640
# [(array([ 63.47345734], dtype=float32), array([ 480.], dtype=float32), array([ 291.8487854], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.47345734], dtype=float32), array([ 480.], dtype=float32), array([ 291.8487854], dtype=float32), array([ 330.], dtype=float32)), (array([ 8.07247639], dtype=float32), array([ 329.980896], dtype=float32), array([ 192.86332703], dtype=float32), array([ 479.97225952], dtype=float32))]
# 480 640
# [(array([ 63.45776367], dtype=float32), array([ 480.], dtype=float32), array([ 291.93792725], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.45776367], dtype=float32), array([ 480.], dtype=float32), array([ 291.93792725], dtype=float32), array([ 330.], dtype=float32)), (array([ 2.99850392], dtype=float32), array([ 329.98294067], dtype=float32), array([ 188.17605591], dtype=float32), array([ 479.97525024], dtype=float32))]
# 480 640
# [(array([ 63.39793015], dtype=float32), array([ 480.], dtype=float32), array([ 292.10168457], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.39793015], dtype=float32), array([ 480.], dtype=float32), array([ 292.10168457], dtype=float32), array([ 330.], dtype=float32)), (array([-3.42061329], dtype=float32), array([ 329.98529053], dtype=float32), array([ 182.04878235], dtype=float32), array([ 479.97869873], dtype=float32))]
# 480 640
# [(array([ 63.38619995], dtype=float32), array([ 480.], dtype=float32), array([ 292.18188477], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.38619995], dtype=float32), array([ 480.], dtype=float32), array([ 292.18188477], dtype=float32), array([ 330.], dtype=float32)), (array([-8.20615101], dtype=float32), array([ 329.98724365], dtype=float32), array([ 177.64312744], dtype=float32), array([ 479.98153687], dtype=float32))]
# 480 640
# [(array([ 63.3578186], dtype=float32), array([ 480.], dtype=float32), array([ 292.28973389], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.3578186], dtype=float32), array([ 480.], dtype=float32), array([ 292.28973389], dtype=float32), array([ 330.], dtype=float32)), (array([-13.46498394], dtype=float32), array([ 329.98928833], dtype=float32), array([ 172.72525024], dtype=float32), array([ 479.98452759], dtype=float32))]
# 480 640
# [(array([ 63.35577774], dtype=float32), array([ 480.], dtype=float32), array([ 292.35070801], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.35577774], dtype=float32), array([ 480.], dtype=float32), array([ 292.35070801], dtype=float32), array([ 330.], dtype=float32)), (array([-17.74702454], dtype=float32), array([ 329.99108887], dtype=float32), array([ 168.82485962], dtype=float32), array([ 479.98712158], dtype=float32))]
# 480 640
# [(array([ 63.3569603], dtype=float32), array([ 480.], dtype=float32), array([ 292.40466309], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.3569603], dtype=float32), array([ 480.], dtype=float32), array([ 292.40466309], dtype=float32), array([ 330.], dtype=float32)), (array([-21.81654549], dtype=float32), array([ 329.99282837], dtype=float32), array([ 165.13346863], dtype=float32), array([ 479.98965454], dtype=float32))]
# 480 640
# [(array([ 63.36174393], dtype=float32), array([ 480.], dtype=float32), array([ 292.45095825], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.36174393], dtype=float32), array([ 480.], dtype=float32), array([ 292.45095825], dtype=float32), array([ 330.], dtype=float32)), (array([-25.6604538], dtype=float32), array([ 329.99450684], dtype=float32), array([ 161.6648407], dtype=float32), array([ 479.99206543], dtype=float32))]
# 480 640
# [(array([ 63.37852859], dtype=float32), array([ 480.], dtype=float32), array([ 292.47463989], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.37852859], dtype=float32), array([ 480.], dtype=float32), array([ 292.47463989], dtype=float32), array([ 330.], dtype=float32)), (array([-28.96763992], dtype=float32), array([ 329.9960022], dtype=float32), array([ 158.74310303], dtype=float32), array([ 479.9942627], dtype=float32))]
# 480 640
# [(array([ 63.39180756], dtype=float32), array([ 480.], dtype=float32), array([ 292.50311279], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.39180756], dtype=float32), array([ 480.], dtype=float32), array([ 292.50311279], dtype=float32), array([ 330.], dtype=float32)), (array([-32.29792023], dtype=float32), array([ 329.99749756], dtype=float32), array([ 155.78305054], dtype=float32), array([ 479.99642944], dtype=float32))]
# 480 640
# [(array([ 63.41640854], dtype=float32), array([ 480.], dtype=float32), array([ 292.50997925], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.41640854], dtype=float32), array([ 480.], dtype=float32), array([ 292.50997925], dtype=float32), array([ 330.], dtype=float32)), (array([-35.10096359], dtype=float32), array([ 329.99884033], dtype=float32), array([ 153.35791016], dtype=float32), array([ 479.99835205], dtype=float32))]
# 480 640
# [(array([ 63.43349838], dtype=float32), array([ 480.], dtype=float32), array([ 292.52890015], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.43349838], dtype=float32), array([ 480.], dtype=float32), array([ 292.52890015], dtype=float32), array([ 330.], dtype=float32)), (array([-38.08708191], dtype=float32), array([ 330.00021362], dtype=float32), array([ 150.7293396], dtype=float32), array([ 480.00033569], dtype=float32))]
# 480 640
# [(array([ 63.45845795], dtype=float32), array([ 480.], dtype=float32), array([ 292.53234863], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.45845795], dtype=float32), array([ 480.], dtype=float32), array([ 292.53234863], dtype=float32), array([ 330.], dtype=float32)), (array([-40.67427063], dtype=float32), array([ 330.00146484], dtype=float32), array([ 148.5020752], dtype=float32), array([ 480.00213623], dtype=float32))]
# 480 640
# [(array([ 63.48289108], dtype=float32), array([ 480.], dtype=float32), array([ 292.53543091], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.48289108], dtype=float32), array([ 480.], dtype=float32), array([ 292.53543091], dtype=float32), array([ 330.], dtype=float32)), (array([-43.18634796], dtype=float32), array([ 330.00268555], dtype=float32), array([ 146.34043884], dtype=float32), array([ 480.00390625], dtype=float32))]
# 480 640
# [(array([ 63.51331329], dtype=float32), array([ 480.], dtype=float32), array([ 292.52633667], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.51331329], dtype=float32), array([ 480.], dtype=float32), array([ 292.52633667], dtype=float32), array([ 330.], dtype=float32)), (array([-45.36443329], dtype=float32), array([ 330.00378418], dtype=float32), array([ 144.51182556], dtype=float32), array([ 480.00552368], dtype=float32))]
# 480 640
# [(array([ 63.53789139], dtype=float32), array([ 480.], dtype=float32), array([ 292.5267334], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.53789139], dtype=float32), array([ 480.], dtype=float32), array([ 292.5267334], dtype=float32), array([ 330.], dtype=float32)), (array([-47.69021606], dtype=float32), array([ 330.00491333], dtype=float32), array([ 142.52017212], dtype=float32), array([ 480.00717163], dtype=float32))]
# 480 640
# [(array([ 63.57538986], dtype=float32), array([ 480.], dtype=float32), array([ 292.50216675], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.57538986], dtype=float32), array([ 480.], dtype=float32), array([ 292.50216675], dtype=float32), array([ 330.], dtype=float32)), (array([-49.39283752], dtype=float32), array([ 330.00585938], dtype=float32), array([ 141.15843201], dtype=float32), array([ 480.00854492], dtype=float32))]
# 480 640
# [(array([ 63.59938049], dtype=float32), array([ 480.], dtype=float32), array([ 292.50137329], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.59938049], dtype=float32), array([ 480.], dtype=float32), array([ 292.50137329], dtype=float32), array([ 330.], dtype=float32)), (array([-51.57658768], dtype=float32), array([ 330.00692749], dtype=float32), array([ 139.29290771], dtype=float32), array([ 480.01010132], dtype=float32))]
# 480 640
# [(array([ 63.61558533], dtype=float32), array([ 480.], dtype=float32), array([ 292.51419067], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.61558533], dtype=float32), array([ 480.], dtype=float32), array([ 292.51419067], dtype=float32), array([ 330.], dtype=float32)), (array([-54.03371811], dtype=float32), array([ 330.00808716], dtype=float32), array([ 137.14056396], dtype=float32), array([ 480.01174927], dtype=float32))]
# 480 640
# [(array([ 63.64635468], dtype=float32), array([ 480.], dtype=float32), array([ 292.49908447], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.64635468], dtype=float32), array([ 480.], dtype=float32), array([ 292.49908447], dtype=float32), array([ 330.], dtype=float32)), (array([-55.80146408], dtype=float32), array([ 330.0090332], dtype=float32), array([ 135.68644714], dtype=float32), array([ 480.01309204], dtype=float32))]
# 480 640
# [(array([ 63.6879425], dtype=float32), array([ 480.], dtype=float32), array([ 292.46261597], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.6879425], dtype=float32), array([ 480.], dtype=float32), array([ 292.46261597], dtype=float32), array([ 330.], dtype=float32)), (array([-56.20048523], dtype=float32), array([ 330.00979614], dtype=float32), array([ 135.56430054], dtype=float32), array([ 480.01419067], dtype=float32))]
# 480 640
# [(array([ 63.72483063], dtype=float32), array([ 480.], dtype=float32), array([ 292.43383789], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 63.72483063], dtype=float32), array([ 480.], dtype=float32), array([ 292.43383789], dtype=float32), array([ 330.], dtype=float32)), (array([-56.89527893], dtype=float32), array([ 330.01055908], dtype=float32), array([ 133.61268616], dtype=float32), array([ 480.01535034], dtype=float32))]
# 480 640
# [(array([ 63.75955582], dtype=float32), array([ 480.], dtype=float32), array([ 292.40820312], dtype=float32), array([ 330.], dtype=float32))]
# ...
# 480 640
# [(array([ 110.39854431], dtype=float32), array([ 480.], dtype=float32), array([ 241.18841553], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 110.39854431], dtype=float32), array([ 480.], dtype=float32), array([ 241.18841553], dtype=float32), array([ 330.], dtype=float32)), (array([ 69.38227844], dtype=float32), array([ 330.00231934], dtype=float32), array([ 254.80464172], dtype=float32), array([ 480.00338745], dtype=float32))]
# 480 640
# [(array([ 114.02075195], dtype=float32), array([ 480.], dtype=float32), array([ 245.91442871], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 114.02075195], dtype=float32), array([ 480.], dtype=float32), array([ 245.91442871], dtype=float32), array([ 330.], dtype=float32)), (array([ 82.88661957], dtype=float32), array([ 330.00216675], dtype=float32), array([ 269.68237305], dtype=float32), array([ 480.00317383], dtype=float32))]
# 480 640
# [(array([ 117.47364044], dtype=float32), array([ 480.], dtype=float32), array([ 250.47537231], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 117.47364044], dtype=float32), array([ 480.], dtype=float32), array([ 250.47537231], dtype=float32), array([ 330.], dtype=float32)), (array([ 96.09226227], dtype=float32), array([ 330.00204468], dtype=float32), array([ 284.24325562], dtype=float32), array([ 480.00296021], dtype=float32))]
# 480 640
# [(array([ 120.43296814], dtype=float32), array([ 480.], dtype=float32), array([ 254.61549377], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 120.43296814], dtype=float32), array([ 480.], dtype=float32), array([ 254.61549377], dtype=float32), array([ 330.], dtype=float32)), (array([ 108.56455994], dtype=float32), array([ 330.00192261], dtype=float32), array([ 297.60342407], dtype=float32), array([ 480.00274658], dtype=float32))]
# 480 640
# [(array([ 123.34339142], dtype=float32), array([ 480.], dtype=float32), array([ 258.65725708], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 123.34339142], dtype=float32), array([ 480.], dtype=float32), array([ 258.65725708], dtype=float32), array([ 330.], dtype=float32)), (array([ 120.65846252], dtype=float32), array([ 330.00180054], dtype=float32), array([ 310.51480103], dtype=float32), array([ 480.00256348], dtype=float32))]
# 480 640
# [(array([ 125.54804993], dtype=float32), array([ 480.], dtype=float32), array([ 262.53930664], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 125.54804993], dtype=float32), array([ 480.], dtype=float32), array([ 262.53930664], dtype=float32), array([ 330.], dtype=float32)), (array([ 132.5423584], dtype=float32), array([ 330.00167847], dtype=float32), array([ 322.77380371], dtype=float32), array([ 480.00238037], dtype=float32))]
# 480 640
# [(array([ 128.095047], dtype=float32), array([ 480.], dtype=float32), array([ 266.45559692], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 128.095047], dtype=float32), array([ 480.], dtype=float32), array([ 266.45559692], dtype=float32), array([ 330.], dtype=float32)), (array([ 143.99729919], dtype=float32), array([ 330.0015564], dtype=float32), array([ 334.61557007], dtype=float32), array([ 480.00219727], dtype=float32))]
# 480 640
# [(array([ 130.53320312], dtype=float32), array([ 480.], dtype=float32), array([ 270.19290161], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 130.53320312], dtype=float32), array([ 480.], dtype=float32), array([ 270.19290161], dtype=float32), array([ 330.], dtype=float32)), (array([ 154.86709595], dtype=float32), array([ 330.00146484], dtype=float32), array([ 346.20309448], dtype=float32), array([ 480.00204468], dtype=float32))]
# 480 640
# [(array([ 132.93966675], dtype=float32), array([ 480.], dtype=float32), array([ 273.80133057], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 132.93966675], dtype=float32), array([ 480.], dtype=float32), array([ 273.80133057], dtype=float32), array([ 330.], dtype=float32)), (array([ 165.58399963], dtype=float32), array([ 330.00134277], dtype=float32), array([ 357.60876465], dtype=float32), array([ 480.00189209], dtype=float32))]
# 480 640
# [(array([ 135.05134583], dtype=float32), array([ 480.], dtype=float32), array([ 277.11340332], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 135.05134583], dtype=float32), array([ 480.], dtype=float32), array([ 277.11340332], dtype=float32), array([ 330.], dtype=float32)), (array([ 175.63613892], dtype=float32), array([ 330.0012207], dtype=float32), array([ 368.36254883], dtype=float32), array([ 480.0017395], dtype=float32))]
# 480 640
# [(array([ 136.96302795], dtype=float32), array([ 480.], dtype=float32), array([ 280.20504761], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 136.96302795], dtype=float32), array([ 480.], dtype=float32), array([ 280.20504761], dtype=float32), array([ 330.], dtype=float32)), (array([ 185.34921265], dtype=float32), array([ 330.00109863], dtype=float32), array([ 378.34100342], dtype=float32), array([ 480.00158691], dtype=float32))]
# 480 640
# [(array([ 138.82063293], dtype=float32), array([ 480.], dtype=float32), array([ 283.20608521], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 138.82063293], dtype=float32), array([ 480.], dtype=float32), array([ 283.20608521], dtype=float32), array([ 330.], dtype=float32)), (array([ 194.771698], dtype=float32), array([ 330.00097656], dtype=float32), array([ 388.02145386], dtype=float32), array([ 480.00146484], dtype=float32))]
# 480 640
# [(array([ 140.45291138], dtype=float32), array([ 480.], dtype=float32), array([ 285.96072388], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 140.45291138], dtype=float32), array([ 480.], dtype=float32), array([ 285.96072388], dtype=float32), array([ 330.], dtype=float32)), (array([ 203.58772278], dtype=float32), array([ 330.00085449], dtype=float32), array([ 397.08105469], dtype=float32), array([ 480.00134277], dtype=float32))]
# 480 640
# [(array([ 142.24139404], dtype=float32), array([ 480.], dtype=float32), array([ 288.82318115], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 142.24139404], dtype=float32), array([ 480.], dtype=float32), array([ 288.82318115], dtype=float32), array([ 330.], dtype=float32)), (array([ 212.5496521], dtype=float32), array([ 330.00076294], dtype=float32), array([ 406.32388306], dtype=float32), array([ 480.0012207], dtype=float32))]
# 480 640
# [(array([ 143.73834229], dtype=float32), array([ 480.], dtype=float32), array([ 291.38827515], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 143.73834229], dtype=float32), array([ 480.], dtype=float32), array([ 291.38827515], dtype=float32), array([ 330.], dtype=float32)), (array([ 220.93829346], dtype=float32), array([ 330.00067139], dtype=float32), array([ 414.6831665], dtype=float32), array([ 480.00109863], dtype=float32))]
# 480 640
# [(array([ 144.95671082], dtype=float32), array([ 480.], dtype=float32), array([ 293.97790527], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 144.95671082], dtype=float32), array([ 480.], dtype=float32), array([ 293.97790527], dtype=float32), array([ 330.], dtype=float32)), (array([ 229.09545898], dtype=float32), array([ 330.00057983], dtype=float32), array([ 422.84106445], dtype=float32), array([ 480.00097656], dtype=float32))]
# 480 640
# [(array([ 146.06089783], dtype=float32), array([ 480.], dtype=float32), array([ 296.71209717], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 146.06089783], dtype=float32), array([ 480.], dtype=float32), array([ 296.71209717], dtype=float32), array([ 330.], dtype=float32)), (array([ 237.13389587], dtype=float32), array([ 330.00048828], dtype=float32), array([ 430.7545166], dtype=float32), array([ 480.00085449], dtype=float32))]
# 480 640
# [(array([ 147.17062378], dtype=float32), array([ 480.], dtype=float32), array([ 299.13659668], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 147.17062378], dtype=float32), array([ 480.], dtype=float32), array([ 299.13659668], dtype=float32), array([ 330.], dtype=float32)), (array([ 244.93132019], dtype=float32), array([ 330.00039673], dtype=float32), array([ 438.42681885], dtype=float32), array([ 480.00073242], dtype=float32))]
# 480 640
# [(array([ 148.29457092], dtype=float32), array([ 480.], dtype=float32), array([ 301.54501343], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 148.29457092], dtype=float32), array([ 480.], dtype=float32), array([ 301.54501343], dtype=float32), array([ 330.], dtype=float32)), (array([ 252.62055969], dtype=float32), array([ 330.00030518], dtype=float32), array([ 446.05160522], dtype=float32), array([ 480.00061035], dtype=float32))]
# 480 640
# [(array([ 149.11146545], dtype=float32), array([ 480.], dtype=float32), array([ 303.61227417], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 149.11146545], dtype=float32), array([ 480.], dtype=float32), array([ 303.61227417], dtype=float32), array([ 330.], dtype=float32)), (array([ 259.58868408], dtype=float32), array([ 330.00024414], dtype=float32), array([ 452.59280396], dtype=float32), array([ 480.00048828], dtype=float32))]
# 480 640
# [(array([ 150.21182251], dtype=float32), array([ 480.], dtype=float32), array([ 305.94082642], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 150.21182251], dtype=float32), array([ 480.], dtype=float32), array([ 305.94082642], dtype=float32), array([ 330.], dtype=float32)), (array([ 267.00119019], dtype=float32), array([ 330.00018311], dtype=float32), array([ 460.00570679], dtype=float32), array([ 480.00036621], dtype=float32))]
# 480 640
# [(array([ 150.98931885], dtype=float32), array([ 480.], dtype=float32), array([ 307.91030884], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 150.98931885], dtype=float32), array([ 480.], dtype=float32), array([ 307.91030884], dtype=float32), array([ 330.], dtype=float32)), (array([ 273.51712036], dtype=float32), array([ 330.00012207], dtype=float32), array([ 466.0958252], dtype=float32), array([ 480.00024414], dtype=float32))]
# 480 640
# [(array([ 151.74937439], dtype=float32), array([ 480.], dtype=float32), array([ 309.83355713], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 151.74937439], dtype=float32), array([ 480.], dtype=float32), array([ 309.83355713], dtype=float32), array([ 330.], dtype=float32)), (array([ 280.05444336], dtype=float32), array([ 330.00006104], dtype=float32), array([ 471.89642334], dtype=float32), array([ 480.00015259], dtype=float32))]
# 480 640
# [(array([ 152.6834259], dtype=float32), array([ 480.], dtype=float32), array([ 311.91983032], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 152.6834259], dtype=float32), array([ 480.], dtype=float32), array([ 311.91983032], dtype=float32), array([ 330.], dtype=float32)), (array([ 286.7868042], dtype=float32), array([ 330.], dtype=float32), array([ 478.02606201], dtype=float32), array([ 480.00006104], dtype=float32))]
# 480 640
# [(array([ 153.62643433], dtype=float32), array([ 480.], dtype=float32), array([ 314.00085449], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 153.62643433], dtype=float32), array([ 480.], dtype=float32), array([ 314.00085449], dtype=float32), array([ 330.], dtype=float32)), (array([ 293.42211914], dtype=float32), array([ 329.99993896], dtype=float32), array([ 484.05078125], dtype=float32), array([ 479.99996948], dtype=float32))]
# 480 640
# [(array([ 153.37811279], dtype=float32), array([ 480.], dtype=float32), array([ 315.45220947], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 153.37811279], dtype=float32), array([ 480.], dtype=float32), array([ 315.45220947], dtype=float32), array([ 330.], dtype=float32)), (array([ 298.94152832], dtype=float32), array([ 329.99987793], dtype=float32), array([ 488.61672974], dtype=float32), array([ 479.99987793], dtype=float32))]
# 480 640
# [(array([ 152.19532776], dtype=float32), array([ 480.], dtype=float32), array([ 316.93197632], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 152.19532776], dtype=float32), array([ 480.], dtype=float32), array([ 316.93197632], dtype=float32), array([ 330.], dtype=float32)), (array([ 303.56713867], dtype=float32), array([ 329.99981689], dtype=float32), array([ 492.54049683], dtype=float32), array([ 479.99981689], dtype=float32))]
# 480 640
# [(array([ 151.72494507], dtype=float32), array([ 480.], dtype=float32), array([ 318.0539856], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 151.72494507], dtype=float32), array([ 480.], dtype=float32), array([ 318.0539856], dtype=float32), array([ 330.], dtype=float32)), (array([ 308.74838257], dtype=float32), array([ 329.99975586], dtype=float32), array([ 496.72918701], dtype=float32), array([ 479.99972534], dtype=float32))]
# 480 640
# [(array([ 150.9344635], dtype=float32), array([ 480.], dtype=float32), array([ 318.78659058], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 150.9344635], dtype=float32), array([ 480.], dtype=float32), array([ 318.78659058], dtype=float32), array([ 330.], dtype=float32)), (array([ 312.67501831], dtype=float32), array([ 329.99969482], dtype=float32), array([ 500.03277588], dtype=float32), array([ 479.99966431], dtype=float32))]
# 480 640
# [(array([ 150.26734924], dtype=float32), array([ 480.], dtype=float32), array([ 319.61331177], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 150.26734924], dtype=float32), array([ 480.], dtype=float32), array([ 319.61331177], dtype=float32), array([ 330.], dtype=float32)), (array([ 317.2479248], dtype=float32), array([ 329.99963379], dtype=float32), array([ 503.41983032], dtype=float32), array([ 479.99960327], dtype=float32))]
# 480 640
# [(array([ 149.52246094], dtype=float32), array([ 480.], dtype=float32), array([ 320.29855347], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 149.52246094], dtype=float32), array([ 480.], dtype=float32), array([ 320.29855347], dtype=float32), array([ 330.], dtype=float32)), (array([ 321.16217041], dtype=float32), array([ 329.99960327], dtype=float32), array([ 506.51528931], dtype=float32), array([ 479.99957275], dtype=float32))]
# 480 640
# [(array([ 148.83668518], dtype=float32), array([ 480.], dtype=float32), array([ 321.0098877], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 148.83668518], dtype=float32), array([ 480.], dtype=float32), array([ 321.0098877], dtype=float32), array([ 330.], dtype=float32)), (array([ 325.28088379], dtype=float32), array([ 329.99957275], dtype=float32), array([ 509.0045166], dtype=float32), array([ 479.99951172], dtype=float32))]
# 480 640
# [(array([ 148.11972046], dtype=float32), array([ 480.], dtype=float32), array([ 321.63879395], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 148.11972046], dtype=float32), array([ 480.], dtype=float32), array([ 321.63879395], dtype=float32), array([ 330.], dtype=float32)), (array([ 329.12225342], dtype=float32), array([ 329.99954224], dtype=float32), array([ 511.52102661], dtype=float32), array([ 479.9994812], dtype=float32))]
# 480 640
# [(array([ 146.60765076], dtype=float32), array([ 480.], dtype=float32), array([ 322.08673096], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 146.60765076], dtype=float32), array([ 480.], dtype=float32), array([ 322.08673096], dtype=float32), array([ 330.], dtype=float32)), (array([ 332.84915161], dtype=float32), array([ 329.99951172], dtype=float32), array([ 513.69952393], dtype=float32), array([ 479.99945068], dtype=float32))]
# 480 640
# [(array([ 145.2505188], dtype=float32), array([ 480.], dtype=float32), array([ 322.60366821], dtype=float32), array([ 330.], dtype=float32))]
# [(array([ 145.2505188], dtype=float32), array([ 480.], dtype=float32), array([ 322.60366821], dtype=float32), array([ 330.], dtype=float32)), (array([ 336.6293335], dtype=float32), array([ 329.9994812], dtype=float32), array([ 515.70092773], dtype=float32), array([ 479.99942017], dtype=float32))]
